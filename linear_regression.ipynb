# %%
# %load_ext autoreload
# %autoreload 2
import matplotlib.pyplot as plt
import random
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
def regression_function(samples=100) -> ([int], [float]):
    X = []
    Y = []
    for x in range(samples):
        # y = 5 * x + 1
        y = 5 * x + random.uniform(-100, 100)
        X.append(x)
        Y.append(y)

    return X, Y

# %%
def print_function(X: list[int], Y: list[float]):
    fig, ax = plt.subplots()
    ax.scatter(X, Y)
    plt.show()

# %%
X, Y = regression_function()
print_function(X, Y)

# %%
def print_prediction_function(X: list[int], Y: list[float], Y_predicted: list[float]):
    fig, ax = plt.subplots()
    ax.scatter(X, Y)
    ax.plot(X, Y_predicted, 'r')
    plt.show()

# %%
from perceptron.linear_regression import NeuralNetwork

nn = NeuralNetwork()
Y_predicted = nn.predict(X)
print_prediction_function(X, Y, Y_predicted)

# %%
population = [*zip(X, Y)]
training_sample = [*zip(X, Y)]
learning_rate = 0.00001
epochs = 100000
nn.train(training_sample, learning_rate, epochs)
# Out:
# Epoch: 100, Loss: 349292.1539, Weight: 5.0787, Bias: 0.9689
# Epoch: 200, Loss: 349199.9792, Weight: 5.0762, Bias: 1.2067
# Epoch: 300, Loss: 349114.1638, Weight: 5.0738, Bias: 1.4341
# Epoch: 400, Loss: 349034.2312, Weight: 5.0715, Bias: 1.6516
# Epoch: 500, Loss: 348959.7430, Weight: 5.0692, Bias: 1.8598
# Epoch: 600, Loss: 348890.2952, Weight: 5.0671, Bias: 2.0588
# Epoch: 700, Loss: 348825.5155, Weight: 5.0651, Bias: 2.2493
# Epoch: 800, Loss: 348765.0608, Weight: 5.0631, Bias: 2.4315
# Epoch: 900, Loss: 348708.6150, Weight: 5.0613, Bias: 2.6058
# Epoch: 1000, Loss: 348655.8864, Weight: 5.0595, Bias: 2.7725
# Epoch: 1100, Loss: 348606.6062, Weight: 5.0578, Bias: 2.9320
# Epoch: 1200, Loss: 348560.5261, Weight: 5.0562, Bias: 3.0845
# Epoch: 1300, Loss: 348517.4172, Weight: 5.0546, Bias: 3.2305
# Epoch: 1400, Loss: 348477.0680, Weight: 5.0531, Bias: 3.3701
# Epoch: 1500, Loss: 348439.2834, Weight: 5.0517, Bias: 3.5036
# Epoch: 1600, Loss: 348403.8828, Weight: 5.0504, Bias: 3.6314
# ...

# %%
Y_predicted = nn.predict(X)
print_prediction_function(X, Y, Y_predicted)
